# %% [markdown]
# # Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns EIN', 'NAME','AFFILIATION','SPECIAL_CONSIDERATIONS','USE_CASE','ORGANIZATION'.
application_df = application_df.drop(['EIN', 'NAME','AFFILIATION','SPECIAL_CONSIDERATIONS','USE_CASE','ORGANIZATION'], axis=1)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE      17
# CLASSIFICATION        71
# STATUS                 2
# INCOME_AMT             9
# ASK_AMT             8747
# IS_SUCCESSFUL          2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
counts1 = application_df['APPLICATION_TYPE'].value_counts()
counts1
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(counts1[counts1<100].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
counts_classification = application_df['CLASSIFICATION'].value_counts()
counts_classification
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_count = counts_classification[counts_classification>1]
classification_count
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(counts_classification[counts_classification<200].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df_dummies = pd.get_dummies(application_df)
application_df_dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                   False
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                  True                 False                False
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    CLASSIFICATION_Other  INCOME_AMT_0  INCOME_AMT_1-9999  \
# 0                 False          True              False
# 1                 False         False               True
# 2                 False          True              False
# 3                 False         False              False
# 4                 False         False              False
#
#    INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                    True                     False               False
# 4                   False                      True               False
#
#    INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  INCOME_AMT_50M+  \
# 0             False                   False            False
# 1             False                   False            False
# 2             False                   False            False
# 3             False                   False            False
# 4             False                   False            False
#
#    INCOME_AMT_5M-10M
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
#
# [5 rows x 27 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_df_dummies['IS_SUCCESSFUL'].values
X = application_df_dummies.drop(columns=['IS_SUCCESSFUL']).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len( X_train_scaled[0])

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=120, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=85, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=40, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_37 (Dense)            (None, 120)               3240
#
#  dense_38 (Dense)            (None, 85)                10285
#
#  dense_39 (Dense)            (None, 40)                3440
#
#  dense_40 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 17006 (66.43 KB)
# Trainable params: 17006 (66.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=150)
# Out:
# Epoch 1/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6311 - accuracy: 0.6287
# Epoch 2/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6307 - accuracy: 0.6295
# Epoch 3/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6308 - accuracy: 0.6290
# Epoch 4/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6310 - accuracy: 0.6297
# Epoch 5/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6312 - accuracy: 0.6305
# Epoch 6/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6311 - accuracy: 0.6286
# Epoch 7/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6308 - accuracy: 0.6300
# Epoch 8/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6310 - accuracy: 0.6298
# Epoch 9/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6309 - accuracy: 0.6293
# Epoch 10/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6311 - accuracy: 0.6286
# Epoch 11/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6307 - accuracy: 0.6293
# Epoch 12/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6309 - accuracy: 0.6286
# Epoch 13/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6309 - accuracy: 0.6293
# Epoch 14/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6306 - accuracy: 0.6301
# Epoch 15/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6325 - accuracy: 0.6291
# Epoch 16/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6307 - accuracy: 0.6298
# Epoch 17/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6307 - accuracy: 0.6298
# Epoch 18/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6308 - accuracy: 0.6285
# Epoch 19/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6312 - accuracy: 0.6289
# Epoch 20/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6307 - accuracy: 0.6291
# Epoch 21/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6310 - accuracy: 0.6291
# Epoch 22/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6312 - accuracy: 0.6291
# Epoch 23/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6310 - accuracy: 0.6295
# Epoch 24/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6309 - accuracy: 0.6290
# Epoch 25/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6308 - accuracy: 0.6291
# Epoch 26/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6310 - accuracy: 0.6296
# Epoch 27/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6310 - accuracy: 0.6286
# Epoch 28/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6310 - accuracy: 0.6286
# Epoch 29/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6306 - accuracy: 0.6295
# Epoch 30/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6310 - accuracy: 0.6281
# Epoch 31/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6312 - accuracy: 0.6295
# Epoch 32/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6307 - accuracy: 0.6295
# Epoch 33/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6307 - accuracy: 0.6297
# Epoch 34/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6306 - accuracy: 0.6295
# Epoch 35/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6309 - accuracy: 0.6291
# Epoch 36/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6311 - accuracy: 0.6287
# Epoch 37/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6313 - accuracy: 0.6295
# Epoch 38/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6309 - accuracy: 0.6308
# Epoch 39/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6308 - accuracy: 0.6305
# Epoch 40/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6307 - accuracy: 0.6291
# Epoch 41/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6308 - accuracy: 0.6292
# Epoch 42/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6308 - accuracy: 0.6298
# Epoch 43/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6308 - accuracy: 0.6291
# Epoch 44/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6307 - accuracy: 0.6291
# Epoch 45/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6306 - accuracy: 0.6314
# Epoch 46/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6308 - accuracy: 0.6291
# Epoch 47/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6307 - accuracy: 0.6278
# Epoch 48/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6306 - accuracy: 0.6311
# Epoch 49/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6310 - accuracy: 0.6274
# Epoch 50/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6308 - accuracy: 0.6288
# Epoch 51/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6309 - accuracy: 0.6284
# Epoch 52/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6310 - accuracy: 0.6287
# Epoch 53/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6309 - accuracy: 0.6288
# Epoch 54/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6306 - accuracy: 0.6291
# Epoch 55/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6306 - accuracy: 0.6295
# Epoch 56/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6307 - accuracy: 0.6293
# Epoch 57/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6305 - accuracy: 0.6293
# Epoch 58/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6305 - accuracy: 0.6273
# Epoch 59/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6307 - accuracy: 0.6297
# Epoch 60/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6310 - accuracy: 0.6293
# Epoch 61/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6309 - accuracy: 0.6295
# Epoch 62/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6312 - accuracy: 0.6290
# Epoch 63/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6309 - accuracy: 0.6294
# Epoch 64/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6306 - accuracy: 0.6284
# Epoch 65/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6306 - accuracy: 0.6288
# Epoch 66/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6307 - accuracy: 0.6295
# Epoch 67/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6308 - accuracy: 0.6299
# Epoch 68/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6308 - accuracy: 0.6300
# Epoch 69/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6308 - accuracy: 0.6296
# Epoch 70/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6306 - accuracy: 0.6286
# Epoch 71/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6305 - accuracy: 0.6300
# Epoch 72/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6307 - accuracy: 0.6292
# Epoch 73/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6305 - accuracy: 0.6298
# Epoch 74/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6304 - accuracy: 0.6278
# Epoch 75/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6308 - accuracy: 0.6295
# Epoch 76/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6305 - accuracy: 0.6295
# Epoch 77/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6308 - accuracy: 0.6300
# Epoch 78/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6305 - accuracy: 0.6303
# Epoch 79/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6305 - accuracy: 0.6274
# Epoch 80/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6306 - accuracy: 0.6283
# Epoch 81/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6306 - accuracy: 0.6298
# Epoch 82/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6307 - accuracy: 0.6281
# Epoch 83/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6311 - accuracy: 0.6286
# Epoch 84/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6308 - accuracy: 0.6302
# Epoch 85/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6309 - accuracy: 0.6296
# Epoch 86/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6303 - accuracy: 0.6291
# Epoch 87/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6304 - accuracy: 0.6280
# Epoch 88/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6304 - accuracy: 0.6299
# Epoch 89/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6309 - accuracy: 0.6288
# Epoch 90/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6305 - accuracy: 0.6303
# Epoch 91/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6303 - accuracy: 0.6285
# Epoch 92/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6304 - accuracy: 0.6283
# Epoch 93/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6307 - accuracy: 0.6297
# Epoch 94/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6304 - accuracy: 0.6293
# Epoch 95/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6310 - accuracy: 0.6288
# Epoch 96/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6303 - accuracy: 0.6282
# Epoch 97/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6304 - accuracy: 0.6296
# Epoch 98/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6304 - accuracy: 0.6299
# Epoch 99/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6304 - accuracy: 0.6301
# Epoch 100/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6305 - accuracy: 0.6295
# Epoch 101/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6308 - accuracy: 0.6295
# Epoch 102/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6303 - accuracy: 0.6298
# Epoch 103/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6302 - accuracy: 0.6285
# Epoch 104/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6305 - accuracy: 0.6291
# Epoch 105/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6319 - accuracy: 0.6293
# Epoch 106/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6303 - accuracy: 0.6286
# Epoch 107/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6301 - accuracy: 0.6298
# Epoch 108/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6303 - accuracy: 0.6292
# Epoch 109/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6304 - accuracy: 0.6292
# Epoch 110/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6302 - accuracy: 0.6293
# Epoch 111/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6303 - accuracy: 0.6293
# Epoch 112/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6305 - accuracy: 0.6296
# Epoch 113/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6304 - accuracy: 0.6291
# Epoch 114/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6304 - accuracy: 0.6290
# Epoch 115/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6303 - accuracy: 0.6295
# Epoch 116/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6305 - accuracy: 0.6300
# Epoch 117/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6308 - accuracy: 0.6307
# Epoch 118/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6309 - accuracy: 0.6296
# Epoch 119/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6303 - accuracy: 0.6296
# Epoch 120/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6304 - accuracy: 0.6298
# Epoch 121/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6302 - accuracy: 0.6300
# Epoch 122/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6308 - accuracy: 0.6300
# Epoch 123/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6304 - accuracy: 0.6295
# Epoch 124/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6307 - accuracy: 0.6295
# Epoch 125/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6324 - accuracy: 0.6293
# Epoch 126/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6302 - accuracy: 0.6291
# Epoch 127/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6303 - accuracy: 0.6295
# Epoch 128/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6302 - accuracy: 0.6294
# Epoch 129/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6309 - accuracy: 0.6288
# Epoch 130/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6301 - accuracy: 0.6296
# Epoch 131/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6302 - accuracy: 0.6297
# Epoch 132/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6302 - accuracy: 0.6289
# Epoch 133/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6305 - accuracy: 0.6299
# Epoch 134/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6304 - accuracy: 0.6293
# Epoch 135/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6302 - accuracy: 0.6297
# Epoch 136/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6303 - accuracy: 0.6296
# Epoch 137/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6302 - accuracy: 0.6298
# Epoch 138/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6300 - accuracy: 0.6296
# Epoch 139/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6320 - accuracy: 0.6296
# Epoch 140/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6308 - accuracy: 0.6281
# Epoch 141/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6303 - accuracy: 0.6301
# Epoch 142/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6304 - accuracy: 0.6300
# Epoch 143/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6303 - accuracy: 0.6299
# Epoch 144/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6301 - accuracy: 0.6296
# Epoch 145/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6301 - accuracy: 0.6300
# Epoch 146/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6302 - accuracy: 0.6273
# Epoch 147/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6305 - accuracy: 0.6298
# Epoch 148/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6300 - accuracy: 0.6302
# Epoch 149/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6301 - accuracy: 0.6272
# Epoch 150/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6301 - accuracy: 0.6295

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6586 - accuracy: 0.6217 - 330ms/epoch - 1ms/step
# Loss: 0.658562421798706, Accuracy: 0.6216909885406494

# %%
# Export our model to HDF5 file
from google.colab import files

nn.save('./Models/AlphabetSoupCharity_Optimization.h5')
files.download('./Models/AlphabetSoupCharity_Optimization.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
